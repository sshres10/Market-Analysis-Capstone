# %%
import pandas as pd

# %%
home_resale = pd.read_csv('Home Resale.csv')
new_construction = pd.read_csv('New Construction.csv')
sold_houses = pd.read_csv('Sold Houses One Year.csv')

# %%
print(home_resale.head())
# Out:
#                                            SALE TYPE  SOLD DATE  \
# 0  In accordance with local MLS rules, some MLS l...        NaN
# 1                                        MLS Listing        NaN
# 2                                        MLS Listing        NaN
# 3                                        MLS Listing        NaN
# 4                                        MLS Listing        NaN
#
#                PROPERTY TYPE              ADDRESS       CITY  \
# 0                        NaN                  NaN        NaN
# 1  Single Family Residential       3640 Byron Cir  Frederick
# 2  Single Family Residential      1809 Fairway Ln  Frederick
# 3  Single Family Residential  6905 Summerswood Dr  Frederick
# 4  Single Family Residential        3403 Mantz Ln  Frederick
#
#   STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ...  STATUS  \
# 0               NaN                 NaN       NaN   NaN    NaN  ...     NaN
# ...

# %%
print(home_resale.columns)
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
columns_to_drop = [
    'HOA/MONTH', 'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME', 
    'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)', 
    'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED'
]

# %%
home_resale_cleaned = home_resale.drop(columns=columns_to_drop, axis=1)

# %%
print("Remaining Columns:")
print(home_resale_cleaned.columns)
# Out:
# Remaining Columns:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'STATUS', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
home_resale_cleaned.head(10)
# Out:
#                                            SALE TYPE  SOLD DATE  \
# 0  In accordance with local MLS rules, some MLS l...        NaN
# 1                                        MLS Listing        NaN
# 2                                        MLS Listing        NaN
# 3                                        MLS Listing        NaN
# 4                                        MLS Listing        NaN
# 5                                        MLS Listing        NaN
# 6                                        MLS Listing        NaN
# 7                                        MLS Listing        NaN
# 8                                        MLS Listing        NaN
# 9                                        MLS Listing        NaN
#
#                PROPERTY TYPE              ADDRESS       CITY  \
# 0                        NaN                  NaN        NaN
# 1  Single Family Residential       3640 Byron Cir  Frederick
# 2  Single Family Residential      1809 Fairway Ln  Frederick
# ...

# %%
home_resale_cleaned = home_resale_cleaned[~home_resale_cleaned['SALE TYPE'].str.contains('In accordance with local MLS rules', na=False)]

# %%
home_resale_cleaned.head(10)
# Out:
#       SALE TYPE  SOLD DATE              PROPERTY TYPE              ADDRESS  \
# 1   MLS Listing        NaN  Single Family Residential       3640 Byron Cir
# 2   MLS Listing        NaN  Single Family Residential      1809 Fairway Ln
# 3   MLS Listing        NaN  Single Family Residential  6905 Summerswood Dr
# 4   MLS Listing        NaN  Single Family Residential        3403 Mantz Ln
# 5   MLS Listing        NaN  Single Family Residential  1009 Eastbourne Ter
# 6   MLS Listing        NaN  Single Family Residential  2113 Rocky Gorge Ct
# 7   MLS Listing        NaN  Single Family Residential  7094 Autumn Leaf Ln
# 8   MLS Listing        NaN  Single Family Residential     312 Faversham Pl
# 9   MLS Listing        NaN  Single Family Residential       2029 Chapel Ct
# 10  MLS Listing        NaN  Single Family Residential     611 Humberson Ln
#
#          CITY STATE OR PROVINCE  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# ...

# %%
# Display the number of rows
print(f"Number of rows: {len(home_resale_cleaned)}")
# Out:
# Number of rows: 80
